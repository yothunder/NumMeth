# %% [markdown]
# # 11 - READING AND WRITING DATA

# %% [markdown]
# ## Summary
# 1. Data must often be stored to a disk for a later Python session or for reading by other programs.
# 2. Data created by other programs may have to be read by Python.
# 3. Python has functions to read and write data in several standard forms: TXT, CSV, pickle, and HDF5.

# %% [markdown]
# ## Problems

# %% [markdown]
# ![11.JPG](attachment:11.JPG)
