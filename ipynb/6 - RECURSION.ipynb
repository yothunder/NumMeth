# %% [markdown]
# # 6 - RECURSION

# %% [markdown]
# ## Summary
# 1. A recursive function is a function that calls itself.
# 2. Recursive functions are useful when problems have a hierarchical structure rather than an iterative structure.
# 3. Divide-and-conquer is a powerful problem-solving strategy that can be used to solve difficult problems.

# %% [markdown]
# ## Problems

# %% [markdown]
# ![6_1.JPG](attachment:6_1.JPG)

# %% [markdown]
# ![6_2.JPG](attachment:6_2.JPG)

# %% [markdown]
# ![6_3.JPG](attachment:6_3.JPG)

# %% [markdown]
# ![6_4.JPG](attachment:6_4.JPG)

# %% [markdown]
# ![6_5.JPG](attachment:6_5.JPG)

# %% [markdown]
# ![6_6.JPG](attachment:6_6.JPG)

# %% [markdown]
# ![6_7.JPG](attachment:6_7.JPG)

# %% [markdown]
# ![6_8_1.JPG](attachment:6_8_1.JPG)

# %% [markdown]
# ![6_8_2.JPG](attachment:6_8_2.JPG)

# %% [markdown]
# ![6_9_1.JPG](attachment:6_9_1.JPG)

# %% [markdown]
# ![6_9_2.JPG](attachment:6_9_2.JPG)

# %% [markdown]
# ![6_10-14.JPG](attachment:6_10-14.JPG)
